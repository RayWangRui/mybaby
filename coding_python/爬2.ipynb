# %%
from urllib import request
from bs4 import BeautifulSoup
from gensim import corpora
from gensim import models
from gensim import similarities

base_url = 'https://newsroom.wcs.org/News-Releases.aspx'

def get_models(data):
    print('model building')
    stop_list = set('for a of the and to in with'.split(' '))
    texts = [[word for word in (d['title'] + d['body']).lower().split() if word not in stop_list] for d in data]
    dictionary = corpora.Dictionary(texts)
    bow_corpus = [dictionary.doc2bow(text) for text in texts]
    tfidf = models.TfidfModel(bow_corpus)
    index = similarities.SparseMatrixSimilarity(tfidf[bow_corpus],
                                                     num_features=len(dictionary.token2id))
    return dictionary, index, tfidf

def get_data(html):
    print('getting data')
    data = []
    soup = BeautifulSoup(html, features="html.parser")
    divs = soup.find_all('div', attrs={'class': 'articleEntry Normal'})
    as_ = soup.find_all('a', attrs={'class':'text-default text-xxl'})
    for i in range (len(divs)):
        p = divs[i].find('p')
        data.append({
            'title': as_[i].string,
            'body': str(divs[i].div.p.string if p is not None else divs[i].div.string),
            'url': as_[i]['href']
        })
    print('get data')
    return data

def search_word(keywords, dictionary,index,tfidf):
    print('serching', keywords)
    words = keywords.lower().split()
    bow = dictionary.doc2bow(words)
    sims = index[tfidf[bow]]
    results = list(enumerate(sims))
    return results

# get url html
def get_url_content(url):
    print('getting html')
    html = request.urlopen(url).read()
    print('get html', url)
    return html

if __name__ == '__main__':
    html = get_url_content(base_url)
    data = get_data(html)
    dictionary, index, tfidf = get_models(data)
    while True:
        key_word = input('input for interesting keywords (0 exit):')
        if key_word == '0':
            break
        results = search_word(key_word, dictionary, index, tfidf)
        print(key_word, 'found:')
        info_count = 0
        for info in results:
            if info[1] != 0:
                info_count = info_count + 1
                print('correlation={}, title={}, url={}, content={}'.format(
                    info[1], data[info[0]]['title'], data[info[0]]['url'], data[info[0]]['body']
                ))
        if info_count == 0:
            print('no found keywords')
# Out:
# getting html
# get html https://newsroom.wcs.org/News-Releases.aspx
# getting data
# get data
# model building
# input for interesting keywords (0 exit):you
# serching you
# you found:
# no found keywords
# input for interesting keywords (0 exit):2020
# serching 2020
# 2020 found:
# no found keywords
# input for interesting keywords (0 exit):word
# serching word
# word found:
# no found keywords
# input for interesting keywords (0 exit):love
# serching love
# love found:
# no found keywords
# input for interesting keywords (0 exit):product
# serching product
# product found:
# no found keywords
# input for interesting keywords (0 exit):new
# serching new
# new found:
# correlation=0.0821107029914856, title=WCS Run for the Wild: Registration Open for New York’s Premiere Spring Event, url=https://newsroom.wcs.org/News-Releases/articleType/ArticleView/articleId/17361/WCS-Run-for-the-Wild-Registration-Open-for-New-Yorks-Premiere-Spring-Event.aspx, content=
#                 Bronx, NY – March 9, 2022 – The event that marks the official start of spring/summer in New York City is officially accepting registrations. The 14th annual Wildlife Conservation Society (WCS) Run for the Wild run/walk at the Bronx Zoo is returns on Saturday, April 30 at the Bronx Zoo.
#
# Each year the WCS Run for the Wild is dedicated to an animal or family of animals in need of conservation support to raise awareness of threats they face. This year’s event is dedicated to hor...
#
# correlation=0.13724246621131897, title=WCS Launches New Visual ID Guide to Identify Illegal Shark Products  , url=https://newsroom.wcs.org/News-Releases/articleType/ArticleView/articleId/17351/WCS-Launches-New-Visual-ID-Guide-to-Identify-Illegal-Shark-Products.aspx, content=None
# correlation=0.07100540399551392, title=Carbon Loss Driven by Tropical Deforestation has Doubled this Century, url=https://newsroom.wcs.org/News-Releases/articleType/ArticleView/articleId/17297/Carbon-Loss-Driven-by-Tropical-Deforestation-has-Doubled-this-Century.aspx, content=A new study reveals that global tropical deforestation has led to a doubling of carbon loss between 2001-2019.
# correlation=0.13200721144676208, title=Scientists Say Environmental DNA Can Detect Whales and Dolphins in New York Waters, url=https://newsroom.wcs.org/News-Releases/articleType/ArticleView/articleId/17294/Scientists-Say-Environmental-DNA-Can-Detect-Whales-and-Dolphins-in-New-York-Waters.aspx, content=A team of scientists used an emerging genetic tool that analyzes DNA in water samples to detect whales and dolphins in New York waters.
# input for interesting keywords (0 exit):city
# serching city
# city found:
# correlation=0.10316969454288483, title=WCS Run for the Wild: Registration Open for New York’s Premiere Spring Event, url=https://newsroom.wcs.org/News-Releases/articleType/ArticleView/articleId/17361/WCS-Run-for-the-Wild-Registration-Open-for-New-Yorks-Premiere-Spring-Event.aspx, content=
#                 Bronx, NY – March 9, 2022 – The event that marks the official start of spring/summer in New York City is officially accepting registrations. The 14th annual Wildlife Conservation Society (WCS) Run for the Wild run/walk at the Bronx Zoo is returns on Saturday, April 30 at the Bronx Zoo.
#
# Each year the WCS Run for the Wild is dedicated to an animal or family of animals in need of conservation support to raise awareness of threats they face. This year’s event is dedicated to hor...
#
# input for interesting keywords (0 exit):animal
# serching animal
# animal found:
# correlation=0.10316969454288483, title=WCS Run for the Wild: Registration Open for New York’s Premiere Spring Event, url=https://newsroom.wcs.org/News-Releases/articleType/ArticleView/articleId/17361/WCS-Run-for-the-Wild-Registration-Open-for-New-Yorks-Premiere-Spring-Event.aspx, content=
#                 Bronx, NY – March 9, 2022 – The event that marks the official start of spring/summer in New York City is officially accepting registrations. The 14th annual Wildlife Conservation Society (WCS) Run for the Wild run/walk at the Bronx Zoo is returns on Saturday, April 30 at the Bronx Zoo.
#
# Each year the WCS Run for the Wild is dedicated to an animal or family of animals in need of conservation support to raise awareness of threats they face. This year’s event is dedicated to hor...
